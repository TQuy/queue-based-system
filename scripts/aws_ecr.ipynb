# %%
# !aws ecr get-login-password | docker login --username AWS --password-stdin $(aws sts get-caller-identity --query Account --output text).dkr.ecr.$(aws configure get region).amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/quynt/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credential-stores
#
# Login Succeeded

# %%
# !aws ecr create-repository --repository-name media-server &&\
aws ecr create-repository --repository-name media-worker
# Out:
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-east-1:211125780173:repository/media-server",
#         "registryId": "211125780173",
#         "repositoryName": "media-server",
#         "repositoryUri": "211125780173.dkr.ecr.us-east-1.amazonaws.com/media-server",
#         "createdAt": "2026-01-28T14:52:30.699000+07:00",
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": false
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }

# %%
# !export REPO_URL="$(aws sts get-caller-identity --query Account --output text).dkr.ecr.$(aws configure get region).amazonaws.com/media-server" &&\
    echo $REPO_URL &&\
        docker tag thequy/media-server:v1.0.0 $REPO_URL:v1.0.0 &&\
            docker push $REPO_URL:v1.0.0 &&\
                docker tag thequy/media-server:v1.0.0 $REPO_URL:latest &&\
                    docker push $REPO_URL:latest
# Out:
# 211125780173.dkr.ecr.us-east-1.amazonaws.com/media-server
# The push refers to repository [211125780173.dkr.ecr.us-east-1.amazonaws.com/media-server]
#
# 43e339f7: Preparing
# 272f1e1d: Preparing
# 13fb7a8a: Preparing
# b360601f: Preparing
# 0d9a70a7: Preparing
# 0b0cdb1c: Preparing
# 26057bd0: Preparing
# 43e339f7: Pushed    46.7MB/42.04MBAv1.0.0: digest: sha256:acdb60ae98a812ad01337e6f379275ab36cad39d1c829021b2a49e2f68c89ba8 size: 1994
# The push refers to repository [211125780173.dkr.ecr.us-east-1.amazonaws.com/media-server]
#
# 43e339f7: Preparing
# 272f1e1d: Preparing
# 13fb7a8a: Preparing
# b360601f: Preparing
# 0d9a70a7: Preparing
# 0b0cdb1c: Preparing
# 26057bd0: Preparing
# b360601f: Layer already exists latest: digest: sha256:acdb60ae98a812ad01337e6f379275ab36cad39d1c829021b2a49e2f68c89ba8 size: 1994

# %%
# !export REPO_URL="$(aws sts get-caller-identity --query Account --output text).dkr.ecr.$(aws configure get region).amazonaws.com/media-worker" &&\
    echo $REPO_URL &&\
        docker tag thequy/media-worker:v1.0.0 $REPO_URL:v1.0.0 &&\
            docker push $REPO_URL:v1.0.0 &&\
                docker tag thequy/media-worker:v1.0.0 $REPO_URL:latest &&\
                    docker push $REPO_URL:latest
# Out:
# 211125780173.dkr.ecr.us-east-1.amazonaws.com/media-worker
# The push refers to repository [211125780173.dkr.ecr.us-east-1.amazonaws.com/media-worker]
#
# aa7b8071: Preparing
# da13a372: Preparing
# 5f5d5a49: Preparing
# b360601f: Preparing
# 0d9a70a7: Preparing
# 0b0cdb1c: Preparing
# 26057bd0: Preparing
# 26057bd0: Pushed   115.9MB/113.8MBv1.0.0: digest: sha256:6e7e848d8de3fdf9fc6c1986e5b05ca99f4d36d31d9dff116ee652c993e11b0f size: 1994
# The push refers to repository [211125780173.dkr.ecr.us-east-1.amazonaws.com/media-worker]
#
# aa7b8071: Preparing
# da13a372: Preparing
# 5f5d5a49: Preparing
# b360601f: Preparing
# 0d9a70a7: Preparing
# 0b0cdb1c: Preparing
# 26057bd0: Preparing
# 26057bd0: Layer already exists latest: digest: sha256:6e7e848d8de3fdf9fc6c1986e5b05ca99f4d36d31d9dff116ee652c993e11b0f size: 1994

# %%
# !aws ecr list-images \
  --repository-name media-server
# Out:
# {
#     "imageIds": [
#         {
#             "imageDigest": "sha256:acdb60ae98a812ad01337e6f379275ab36cad39d1c829021b2a49e2f68c89ba8",
#             "imageTag": "latest"
#         },
#         {
#             "imageDigest": "sha256:acdb60ae98a812ad01337e6f379275ab36cad39d1c829021b2a49e2f68c89ba8",
#             "imageTag": "v1.0.0"
#         }
#     ]
# }
